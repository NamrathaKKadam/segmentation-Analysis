# %%
import pandas as pd

# Load dataset (update the filename accordingly)
df = pd.read_csv(r"C:\Users\Namratha Kadam\OneDrive\Desktop\ifood_df.csv")

# Display the first few rows
df.head()
# Out:
#     Income  Kidhome  Teenhome  Recency  MntWines  MntFruits  MntMeatProducts  \
# 0  58138.0        0         0       58       635         88              546
# 1  46344.0        1         1       38        11          1                6
# 2  71613.0        0         0       26       426         49              127
# 3  26646.0        1         0       26        11          4               20
# 4  58293.0        1         0       94       173         43              118
#
#    MntFishProducts  MntSweetProducts  MntGoldProds  ...  marital_Together  \
# 0              172                88            88  ...                 0
# 1                2                 1             6  ...                 0
# 2              111                21            42  ...                 1
# 3               10                 3             5  ...                 1
# 4               46                27            15  ...                 0
#
# ...

# %%
df.isnull().sum()
# Out:
# Income                  0
# Kidhome                 0
# Teenhome                0
# Recency                 0
# MntWines                0
# MntFruits               0
# MntMeatProducts         0
# MntFishProducts         0
# MntSweetProducts        0
# MntGoldProds            0
# NumDealsPurchases       0
# NumWebPurchases         0
# NumCatalogPurchases     0
# NumStorePurchases       0
# NumWebVisitsMonth       0
# AcceptedCmp3            0
# AcceptedCmp4            0
# AcceptedCmp5            0
# AcceptedCmp1            0
# AcceptedCmp2            0
# Complain                0
# Z_CostContact           0
# Z_Revenue               0
# Response                0
# Age                     0
# Customer_Days           0
# marital_Divorced        0
# marital_Married         0
# marital_Single          0
# marital_Together        0
# marital_Widow           0
# education_2n Cycle      0
# education_Basic         0
# education_Graduation    0
# education_Master        0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2205 entries, 0 to 2204
# Data columns (total 39 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Income                2205 non-null   float64
#  1   Kidhome               2205 non-null   int64
#  2   Teenhome              2205 non-null   int64
#  3   Recency               2205 non-null   int64
#  4   MntWines              2205 non-null   int64
#  5   MntFruits             2205 non-null   int64
#  6   MntMeatProducts       2205 non-null   int64
#  7   MntFishProducts       2205 non-null   int64
#  8   MntSweetProducts      2205 non-null   int64
#  9   MntGoldProds          2205 non-null   int64
#  10  NumDealsPurchases     2205 non-null   int64
#  11  NumWebPurchases       2205 non-null   int64
#  12  NumCatalogPurchases   2205 non-null   int64
#  13  NumStorePurchases     2205 non-null   int64
#  14  NumWebVisitsMonth     2205 non-null   int64
# ...

# %%
df.fillna(method='ffill', inplace=True)  # Forward fill missing values

# %%
df.drop_duplicates(inplace=True)

# %%
df.describe()
# Out:
#               Income      Kidhome     Teenhome      Recency     MntWines  \
# count    2021.000000  2021.000000  2021.000000  2021.000000  2021.000000
# mean    51687.258783     0.443345     0.509649    48.880752   306.492331
# std     20713.046401     0.536196     0.546393    28.950917   337.603877
# min      1730.000000     0.000000     0.000000     0.000000     0.000000
# 25%     35416.000000     0.000000     0.000000    24.000000    24.000000
# 50%     51412.000000     0.000000     0.000000    49.000000   178.000000
# 75%     68274.000000     1.000000     1.000000    74.000000   507.000000
# max    113734.000000     2.000000     2.000000    99.000000  1493.000000
#
#          MntFruits  MntMeatProducts  MntFishProducts  MntSweetProducts  \
# count  2021.000000      2021.000000      2021.000000       2021.000000
# mean     26.364671       166.059871        37.603662         27.268679
# std      39.776518       219.869126        54.892196         41.575454
# ...

# %%
print(df.columns)
# Out:
# Index(['Income', 'Kidhome', 'Teenhome', 'Recency', 'MntWines', 'MntFruits',
#        'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts',
#        'MntGoldProds', 'NumDealsPurchases', 'NumWebPurchases',
#        'NumCatalogPurchases', 'NumStorePurchases', 'NumWebVisitsMonth',
#        'AcceptedCmp3', 'AcceptedCmp4', 'AcceptedCmp5', 'AcceptedCmp1',
#        'AcceptedCmp2', 'Complain', 'Z_CostContact', 'Z_Revenue', 'Response',
#        'Age', 'Customer_Days', 'marital_Divorced', 'marital_Married',
#        'marital_Single', 'marital_Together', 'marital_Widow',
#        'education_2n Cycle', 'education_Basic', 'education_Graduation',
#        'education_Master', 'education_PhD', 'MntTotal', 'MntRegularProds',
#        'AcceptedCmpOverall'],
#       dtype='object')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))
sns.histplot(df['MntTotal'], bins=30, kde=True)
plt.title("Total Spending Distribution")
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm', fmt=".2f", annot_kws={"size": 6})  
plt.xticks(rotation=45, ha='right')
plt.yticks(rotation=0)
plt.title('Feature Correlation Heatmap')
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import silhouette_score

# Load your dataset
df = pd.read_csv(r"C:\Users\Namratha Kadam\OneDrive\Desktop\ifood_df.csv")  

# Selecting relevant features for segmentation
features = ['Income', 'Age', 'MntTotal', 'NumWebPurchases', 
            'NumCatalogPurchases', 'NumStorePurchases', 'NumWebVisitsMonth']

df_segmentation = df[features].dropna()  # Removing missing values

# %%
scaler = StandardScaler()
df_scaled = scaler.fit_transform(df_segmentation)  # Transform to normalized values

# %%
wcss = []  # Within-cluster sum of squares
silhouette_scores = []

for k in range(2, 11):  # Checking for clusters from 2 to 10
    kmeans = KMeans(n_clusters=k, random_state=42,n_init=10)
    kmeans.fit(df_scaled)
    wcss.append(kmeans.inertia_)  # Append WCSS values
    silhouette_scores.append(silhouette_score(df_scaled, kmeans.labels_))  # Silhouette Score

# Plot Elbow Method
plt.figure(figsize=(10,5))
plt.plot(range(2, 11), wcss, marker='o', linestyle='--')
plt.xlabel("Number of Clusters (K)")
plt.ylabel("WCSS")
plt.title("Elbow Method - Optimal K")
plt.show()

# Plot Silhouette Scores
plt.figure(figsize=(10,5))
plt.plot(range(2, 11), silhouette_scores, marker='s', linestyle='--', color='red')
plt.xlabel("Number of Clusters (K)")
plt.ylabel("Silhouette Score")
plt.title("Silhouette Score for Different K Values")
plt.show()

# %%
from sklearn.cluster import KMeans
import seaborn as sns
import matplotlib.pyplot as plt

# Apply KMeans clustering
kmeans = KMeans(n_clusters=4, random_state=42, n_init=10)
df_segmentation['Cluster'] = kmeans.fit_predict(df_segmentation)

# Plot scatterplot
plt.figure(figsize=(10,6))
sns.scatterplot(x=df_segmentation['Income'], 
                y=df_segmentation['MntTotal'], 
                hue=df_segmentation['Cluster'], 
                palette="viridis")
plt.title("Customer Segmentation Based on Income & Total Spend")
plt.xlabel("Income")
plt.ylabel("Total Spend")
plt.show()

# %%
cluster_summary = df_segmentation.groupby('Cluster').mean()
print(cluster_summary)
# Out:
#                Income        Age     MntTotal  NumWebPurchases  \
# Cluster
# 0        79205.921105  52.214990  1310.021696         5.323471
# 1        41217.813084  51.054517   182.995327         3.174455
# 2        60409.165033  54.370915   709.089869         5.624183
# 3        23056.468468  45.362613    56.912162         1.943694
#
#          NumCatalogPurchases  NumStorePurchases  NumWebVisitsMonth
# Cluster
# 0                   5.747535           8.441815           2.865878
# 1                   1.048287           4.049844           6.404984
# 2                   3.339869           7.648693           4.990196
# 3                   0.454955           2.882883           7.092342
